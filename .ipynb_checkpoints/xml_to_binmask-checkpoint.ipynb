# %%
import xml.etree.ElementTree as ET
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
def parse_xml_to_dict(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    output_dict = {}

    for image_elem in root.findall('image'):
        image_name = image_elem.get('name')
        image_w, image_h = image_elem.get('width'), image_elem.get('height')
        labels = {}
        labels['size'] = (image_w, image_h)

        for polygon_elem in image_elem.findall('polygon'):
            label = polygon_elem.get('label')
            points = polygon_elem.get('points').split(';')
            points = [tuple(map(float, point.split(','))) for point in points]

            labels[label] = points

        output_dict[image_name] = labels

    return output_dict

# %%
def get_mask_list_from_dict(xml_dict):
    
    all_masks = []
    images = []
    
    for img_name in xml_dict.keys():
        # img_name = 'INHS_FISH_5124.jpg'

        W = int(xml_dict[img_name]['size'][0])
        H = int(xml_dict[img_name]['size'][1])

        mask = np.zeros((H, W), dtype=np.uint8)

        # Define a list of points representing the polygon
        if 'Head' in xml_dict[img_name].keys():
            points = xml_dict[img_name]['Head']
            polygon_points = np.array([points], dtype=np.int32)
            cv2.fillPoly(mask, polygon_points, 1)

        # Define a list of points representing the polygon
        if 'Eye' in xml_dict[img_name].keys():
            points = xml_dict[img_name]['Eye']
            polygon_points = np.array([points], dtype=np.int32)
            cv2.fillPoly(mask, polygon_points, 2)

        # Define a list of points representing the polygon
        if 'Dorsal Fin' in xml_dict[img_name].keys():
            points = xml_dict[img_name]['Dorsal Fin']
            polygon_points = np.array([points], dtype=np.int32)
            cv2.fillPoly(mask, polygon_points, 3)

        # Define a list of points representing the polygon
        if 'Pectoral Fin' in xml_dict[img_name].keys():
            points = xml_dict[img_name]['Pectoral Fin']
            polygon_points = np.array([points], dtype=np.int32)
            cv2.fillPoly(mask, polygon_points, 4)

        # Define a list of points representing the polygon
        if 'Pelvic Fin' in xml_dict[img_name].keys():
            points = xml_dict[img_name]['Pelvic Fin']
            polygon_points = np.array([points], dtype=np.int32)
            cv2.fillPoly(mask, polygon_points, 5)

        # Define a list of points representing the polygon
        if 'Anal Fin' in xml_dict[img_name].keys():
            points = xml_dict[img_name]['Anal Fin']
            polygon_points = np.array([points], dtype=np.int32)
            cv2.fillPoly(mask, polygon_points, 6)

        # Define a list of points representing the polygon
        if 'Caudal Fin' in xml_dict[img_name].keys():
            points = xml_dict[img_name]['Caudal Fin']
            polygon_points = np.array([points], dtype=np.int32)
            cv2.fillPoly(mask, polygon_points, 7)

        # Define a list of points representing the polygon
        if 'Adipose Fin' in xml_dict[img_name].keys():
            points = xml_dict[img_name]['Adipose Fin']
            polygon_points = np.array([points], dtype=np.int32)
            cv2.fillPoly(mask, polygon_points, 8)
            
        all_masks.append(mask)
        images.append(img_name)
        
    return all_masks, images

# %%
def get_color_data_all(mask):
    colors = {}                            #   Name         Label
    #                                      # ----------------------
    colors[0] = np.array([0, 0, 0])        # Background      0
    colors[1] = np.array([254, 0, 0])      # Head            1
    colors[2] = np.array([0, 254, 0])      # Eye             2
    colors[3] = np.array([0, 0, 254])      # Dorsal Fin      3
    colors[4] = np.array([254, 254, 0])    # Pectoral Fin    4
    colors[5] = np.array([0, 254, 254])    # Pelvic Fin      5
    colors[6] = np.array([254, 0, 254])    # Anal Fin        6
    colors[7] = np.array([254, 254, 254])  # Caudal Fin      7
    colors[8] = np.array([0, 254, 102])    # Adipose Fin     8

    
    shape_0, shape_1 = mask.shape[0], mask.shape[1]
    color_data = np.zeros((shape_0, shape_1, 3))
    
    labels = np.unique(mask)
    
    for label in labels:
        z_r, z_c = np.where(mask == label)
        color_data[z_r, z_c] = colors[label]

    return color_data

# %%
def plot_img_mask(img_name, mask):

    image = Image.open(img_name)

    fig, ax = plt.subplots(1, 3, figsize=(15, 4))

    ax[0].imshow(image)
    ax[0].axis('off')
    ax[0].set_title(f'image: {img_name}')

    ax[1].imshow(get_color_data_all(mask).astype(np.uint8))
    ax[1].axis('off')
    ax[1].set_title('Seg Mask')

    image = Image.open(img_name)

    plt.imshow(
        Image.blend(
            image,
            Image.fromarray(
                get_color_data_all(mask).astype(np.uint8)
            ), 0.5
        )
    )
    ax[2].axis('off')
    ax[2].set_title('Blended')
    plt.show()

# %%
xml_file = 'annotations_2.xml'
xml_dict = parse_xml_to_dict(xml_file)

# %%
masks, image_names = get_mask_list_from_dict(xml_dict)
for idx in range(len(image_names)):
    mask, img_name = masks[idx], image_names[idx]
    plot_img_mask(img_name, mask)

# %%
# import warnings
# warnings.filterwarnings('ignore')
# import numpy as np
# import matplotlib.pyplot as plt
# import requests
# from PIL import Image
# from io import BytesIO
# from lang_sam import LangSAM
# import os
# from tqdm import tqdm

# text_prompt, BOX_THRESHOLD = "fish", 0.30
# model = LangSAM()
# museums = ['INHS', 'OSUM' , 'FMNH' , 'JFBM' ,  'UWZM' ]

# museum = museums[0]

# img_names = os.listdir(f'/raid/maruf/allmuseum/{museum}')

# dest_folder = f'/raid/maruf/fish_img_gen/mask'

# if not os.path.exists(dest_folder):
#     os.makedirs(dest_folder)
    

# for img_name in tqdm(img_names):
#     img = Image.open(f'/raid/maruf/allmuseum/{museum}/{img_name}')
#     image_pil = img.convert("RGB")
#     masks, boxes, phrases, logits = model.predict(image_pil, text_prompt, box_threshold=BOX_THRESHOLD)
    
#     if len(masks) == 0:
#         continue
    
#     mask = masks[0]
    
#     if (mask.shape[0]* mask.shape[1] * 0.20) >= mask.sum():
#         continue
    
#     np.save(f'{dest_folder}/{img_name[:-4]}', mask)
#     # img_array = np.asarray(img).copy()
#     # z_r, z_c = np.where(mask == 0)
#     # img_array[z_r, z_c] = np.array([255, 255, 255])
#     # mod_img = Image.fromarray(mask.astype(np.uint8))
#     # mod_img.save(f'{dest_folder}/{img_name}')

# %%
# image_pil = Image.open('OSUM0018772.jpg').convert("RGB")
# text_prompt, BOX_THRESHOLD = "fish", 0.30
# model = LangSAM()
# masks, boxes, phrases, logits = model.predict(image_pil, text_prompt, box_threshold=BOX_THRESHOLD)

# %%
# def display_image_with_masks(image, masks):
#     num_masks = len(masks)

#     fig, axes = plt.subplots(1, num_masks + 1, figsize=(15, 5))
#     axes[0].imshow(image)
#     axes[0].set_title("Original Image")
#     axes[0].axis('off')

#     for i, mask_np in enumerate(masks):
#         axes[i+1].imshow(mask_np, cmap='gray')
#         axes[i+1].set_title(f"Mask {i+1}")
#         axes[i+1].axis('off')

#     plt.tight_layout()
#     plt.show()

# # Convert masks to numpy arrays
# masks_np = [mask.squeeze().cpu().numpy() for mask in masks]

# # Display the original image and masks side by side
# display_image_with_masks(image_pil, masks_np)

# %%
# img = Image.open('OSUM0018772.jpg')
# img_array = np.asarray(img).copy()
# z_r, z_c = np.where(masks_np[0] == 0)
# img_array[z_r, z_c] = np.array([255, 255, 255])
# mod_img = Image.fromarray(img_array.astype(np.uint8))

# %%
# plt.imshow(mod_img)
# plt.axis('off')
# plt.show()

# %% [markdown]
# ## Metadata

# %%
# import os
# import pandas as pd 

# museums = ['OSUM' , 'FMNH' , 'INHS' , 'JFBM' ,  'UWZM' ]

# total = 0

# for museum in museums:
#     metadata_path = f"/raid/maruf/{museum}/metadata.csv"
#     if os.path.exists(metadata_path):
#         # print(f"Metadata File exists for {museum}")
#         pass
#     df = pd.read_csv(metadata_path, sep='\t')
#     species_name = df['scientificName'].unique()
#     print(f'{museum} #species:', len(species_name))
#     total += len(species_name)
    
# print("\n\nTotal #species:", total)
